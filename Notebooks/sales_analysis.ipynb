# %% [markdown]
# Data Cleaning and understanding.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\Sample - Superstore.csv", encoding='latin1')
print(df.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv(r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\Sample - Superstore.csv", encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.shape
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 1.6 MB
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.select_dtypes(include='object')
df.select_dtypes(include=['int64', 'float64'])
# Out:
# C:\Users\aadis\AppData\Local\Temp\ipykernel_12492\3754484177.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include='object')
#       Row ID  Postal Code     Sales  Quantity  Discount    Profit
# 0          1        42420  261.9600         2      0.00   41.9136
# 1          2        42420  731.9400         3      0.00  219.5820
# 2          3        90036   14.6200         2      0.00    6.8714
# 3          4        33311  957.5775         5      0.45 -383.0310
# 4          5        33311   22.3680         2      0.20    2.5164
# ...      ...          ...       ...       ...       ...       ...
# 9989    9990        33180   25.2480         3      0.20    4.1028
# 9990    9991        92627   91.9600         2      0.00   15.6332
# 9991    9992        92627  258.5760         2      0.20   19.3932
# 9992    9993        92627   29.6000         4      0.00   13.3200
# 9993    9994        92683  243.1600         2      0.00   72.9480
#
# [9994 rows x 6 columns]

# %%
df.drop(columns=['Row ID'], inplace=True)

# %%
df['Postal Code'] = df['Postal Code'].astype(str)

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9993.000000  9993.000000  9993.000000  9993.000000
# mean     229.852846     3.789753     0.156188    28.660971
# std      623.276074     2.225149     0.206457   234.271476
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.731000
# 50%       54.480000     3.000000     0.200000     8.671000
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
import seaborn as sns
sns.boxplot(x=df['Sales'])
# Out:
# <Axes: xlabel='Sales'>

# %%
df = df[df['Sales'] < df['Sales'].quantile(0.99)]

# %%
import seaborn as sns
sns.boxplot(x=df['Profit'])
# Out:
# <Axes: xlabel='Profit'>

# %%
df = df[df['Profit'] < df['Profit'].quantile(0.99)]

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df['profit_margin'] = df['profit'] / df['sales']

# %%
df.to_csv(r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\cleaned_sales_data.csv", index=False)

# %%
df.head()
# Out:
#          order_id  order_date   ship_date       ship_mode customer_id  \
# 0  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city       state  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ... region       product_id         category sub-category  \
# 0  ...  South  FUR-BO-10001798        Furniture    Bookcases
# 1  ...  South  FUR-CH-10000454        Furniture       Chairs
# 2  ...   West  OFF-LA-10000240  Office Supplies       Labels
# 3  ...  South  FUR-TA-10000577        Furniture       Tables
# 4  ...  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit  profit_margin
# 0      0.00   41.9136         0.1600
# 1      0.00  219.5820         0.3000
# 2      0.00    6.8714         0.4700
# 3      0.45 -383.0310        -0.4000
# 4      0.20    2.5164         0.1125
#
# [5 rows x 21 columns]

# %%
df.sample(10)
# Out:
#             order_id  order_date   ship_date       ship_mode customer_id  \
# 6666  CA-2017-122175   5/12/2017   5/14/2017    Second Class    CA-12775
# 6873  CA-2014-124394  10/17/2014  10/22/2014    Second Class    TB-21520
# 4254  CA-2017-163160  10/13/2017  10/16/2017     First Class    TS-21610
# 1497  CA-2017-152485    9/4/2017    9/8/2017  Standard Class    JD-15790
# 5478  CA-2016-121356  11/20/2016  11/24/2016  Standard Class    SJ-20500
# 433   CA-2016-127369    6/6/2016    6/7/2016     First Class    DB-13060
# 6290  US-2015-139675   3/13/2015   3/18/2015    Second Class    NF-18595
# 8158  CA-2017-136238  12/26/2017    1/1/2018  Standard Class    KB-16240
# 2639  CA-2017-108441   6/12/2017   6/18/2017  Standard Class    SB-20170
# 5729  CA-2017-117324   12/8/2017  12/13/2017  Standard Class    JP-15520
#
#         customer_name      segment        country           city  \
# 6666  Cynthia Arntzen     Consumer  United States       Vineland
# 6873  Tracy Blumstein     Consumer  United States       Beaumont
# 4254     Troy Staebel     Consumer  United States       Freeport
# 1497       John Dryer     Consumer  United States        Coppell
# 5478  Shirley Jackson     Consumer  United States         Newark
# 433       Dave Brooks     Consumer  United States         Lowell
# 6290     Nicole Fjeld  Home Office  United States          Chico
# 8158       Karen Bern    Corporate  United States         Odessa
# 2639       Sarah Bern     Consumer  United States  New York City
# 5729    Jeremy Pistek     Consumer  United States        Madison
#
#               state  ...   region       product_id         category  \
# 6666     New Jersey  ...     East  FUR-FU-10000719        Furniture
# 6873          Texas  ...  Central  OFF-BI-10003676  Office Supplies
# 4254       Illinois  ...  Central  OFF-PA-10003127  Office Supplies
# 1497          Texas  ...  Central  OFF-AR-10001940  Office Supplies
# 5478       Delaware  ...     East  OFF-BI-10002133  Office Supplies
# 433   Massachusetts  ...     East  OFF-ST-10003306  Office Supplies
# 6290     California  ...     West  FUR-FU-10001979        Furniture
# 8158          Texas  ...  Central  OFF-PA-10004285  Office Supplies
# 2639       New York  ...     East  OFF-AR-10004691  Office Supplies
# 5729      Wisconsin  ...  Central  OFF-LA-10003510  Office Supplies
#
#      sub-category                                       product_name    sales  \
# 6666  Furnishings                     DAX Cubicle Frames, 8-1/2 x 11   42.850
# 6873      Binders  GBC Standard Recycled Report Covers, Clear Pla...   10.780
# 4254        Paper                                  Easy-staple paper   63.312
# 1497          Art  Sanford Colorific Eraseable Coloring Pencils, ...   13.120
# 5478      Binders  Wilson Jones Elliptical Ring 3 1/2" Capacity B...  128.400
# 433       Storage                                   Letter Size Cart  714.300
# 6290  Furnishings              Dana Halogen Swing-Arm Architect Lamp  327.760
# 8158        Paper                                         Xerox 1959   16.032
# 2639          Art      Boston 1730 StandUp Electric Pencil Sharpener   64.140
# 5729       Labels  Avery 4027 File Folder Labels for Dot Matrix P...   61.060
#
#       quantity  discount    profit  profit_margin
# 6666         5       0.0   15.4260         0.3600
# 6873         5       0.8  -17.2480        -1.6000
# 4254         3       0.2   20.5764         0.3250
# 1497         5       0.2    3.7720         0.2875
# 5478         3       0.0   62.9160         0.4900
# 433          5       0.0  207.1470         0.2900
# 6290         8       0.0   91.7728         0.2800
# 8158         3       0.2    5.6112         0.3500
# 2639         3       0.0   16.6764         0.2600
# 5729         2       0.0   28.0876         0.4600
#
# [10 rows x 21 columns]

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9794 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9794 non-null   str
#  1   order_date     9794 non-null   datetime64[us]
#  2   ship_date      9794 non-null   datetime64[us]
#  3   ship_mode      9794 non-null   str
#  4   customer_id    9794 non-null   str
#  5   customer_name  9794 non-null   str
#  6   segment        9794 non-null   str
#  7   country        9794 non-null   str
#  8   city           9794 non-null   str
#  9   state          9794 non-null   str
#  10  postal_code    9794 non-null   str
#  11  region         9794 non-null   str
#  12  product_id     9794 non-null   str
#  13  category       9794 non-null   str
#  14  sub-category   9794 non-null   str
#  15  product_name   9794 non-null   str
#  16  sales          9794 non-null   float64
#  17  quantity       9794 non-null   int64
#  18  discount       9794 non-null   float64
#  19  profit         9794 non-null   float64
#  20  profit_margin  9794 non-null   float64
# dtypes: datetime64[us](2), float64(4), int64(1), str(14)
# memory usage: 1.6 MB

# %%
df.isnull().sum()
# Out:
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub-category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# profit_margin    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['ship_date'] < df['order_date']]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_id, customer_name, segment, country, city, state, postal_code, region, product_id, category, sub-category, product_name, sales, quantity, discount, profit, profit_margin]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['calculated_margin'] = df['profit'] / df['sales']

# Compare
df[['profit_margin', 'calculated_margin']].head()
# Out:
#    profit_margin  calculated_margin
# 0         0.1600             0.1600
# 1         0.3000             0.3000
# 2         0.4700             0.4700
# 3        -0.4000            -0.4000
# 4         0.1125             0.1125

# %%
(df['profit_margin'] - df['calculated_margin']).abs().sum()
# Out:
# np.float64(0.0)

# %%
df['order_year'] = df['order_date'].dt.year
df['order_month'] = df['order_date'].dt.month
df['delivery_time'] = (df['ship_date'] - df['order_date']).dt.days

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9794 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           9794 non-null   str
#  1   order_date         9794 non-null   datetime64[us]
#  2   ship_date          9794 non-null   datetime64[us]
#  3   ship_mode          9794 non-null   str
#  4   customer_id        9794 non-null   str
#  5   customer_name      9794 non-null   str
#  6   segment            9794 non-null   str
#  7   country            9794 non-null   str
#  8   city               9794 non-null   str
#  9   state              9794 non-null   str
#  10  postal_code        9794 non-null   str
#  11  region             9794 non-null   str
#  12  product_id         9794 non-null   str
#  13  category           9794 non-null   str
#  14  sub-category       9794 non-null   str
#  15  product_name       9794 non-null   str
#  16  sales              9794 non-null   float64
#  17  quantity           9794 non-null   int64
#  18  discount           9794 non-null   float64
#  19  profit             9794 non-null   float64
#  20  profit_margin      9794 non-null   float64
#  21  calculated_margin  9794 non-null   float64
#  22  order_year         9794 non-null   int32
#  23  order_month        9794 non-null   int32
#  24  delivery_time      9794 non-null   int64
# dtypes: datetime64[us](2), float64(5), int32(2), int64(2), str(14)
# memory usage: 1.9 MB

# %%
# Rename the column and save it back to the dataframe
df = df.rename(columns={'sub-category': 'sub_category'})

# %%
df.sample(2)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 459   CA-2015-109638 2015-12-15 2015-12-22  Standard Class    JH-15985
# 5064  CA-2017-122196 2017-09-22 2017-09-24     First Class    CA-12265
#
#            customer_name   segment        country        city       state  \
# 459          Joseph Holt  Consumer  United States     Seattle  Washington
# 5064  Christina Anderson  Consumer  United States  Wilmington    Delaware
#
#       ...           product_name   sales quantity discount    profit  \
# 459   ...  3M Office Air Cleaner  103.92        4      0.0   36.3720
# 5064  ...            GE 30524EE4  391.98        2      0.0  113.6742
#
#      profit_margin  calculated_margin  order_year  order_month  delivery_time
# 459           0.35               0.35        2015           12              7
# 5064          0.29               0.29        2017            9              2
#
# [2 rows x 25 columns]

# %%
df = df.drop(columns=['calculated_margin'])

# %%
# %Y = 4-digit year, %m = month, %d = day
df['order_date'] = df['order_date'].dt.strftime('%Y-%m-%d')

# %%
df['ship_date'] = df['ship_date'].dt.strftime('%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9794 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9794 non-null   str
#  1   order_date     9794 non-null   str
#  2   ship_date      9794 non-null   str
#  3   ship_mode      9794 non-null   str
#  4   customer_id    9794 non-null   str
#  5   customer_name  9794 non-null   str
#  6   segment        9794 non-null   str
#  7   country        9794 non-null   str
#  8   city           9794 non-null   str
#  9   state          9794 non-null   str
#  10  postal_code    9794 non-null   str
#  11  region         9794 non-null   str
#  12  product_id     9794 non-null   str
#  13  category       9794 non-null   str
#  14  sub_category   9794 non-null   str
#  15  product_name   9794 non-null   str
#  16  sales          9794 non-null   float64
#  17  quantity       9794 non-null   int64
#  18  discount       9794 non-null   float64
#  19  profit         9794 non-null   float64
#  20  profit_margin  9794 non-null   float64
#  21  order_year     9794 non-null   int32
#  22  order_month    9794 non-null   int32
#  23  delivery_time  9794 non-null   int64
# dtypes: float64(4), int32(2), int64(2), str(16)
# memory usage: 1.8 MB

# %%
# This converts the column to a standard Pandas Datetime object
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
# This converts the column to a standard Pandas Datetime object
df['ship_date'] = pd.to_datetime(df['ship_date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9794 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9794 non-null   str
#  1   order_date     9794 non-null   datetime64[us]
#  2   ship_date      9794 non-null   datetime64[us]
#  3   ship_mode      9794 non-null   str
#  4   customer_id    9794 non-null   str
#  5   customer_name  9794 non-null   str
#  6   segment        9794 non-null   str
#  7   country        9794 non-null   str
#  8   city           9794 non-null   str
#  9   state          9794 non-null   str
#  10  postal_code    9794 non-null   str
#  11  region         9794 non-null   str
#  12  product_id     9794 non-null   str
#  13  category       9794 non-null   str
#  14  sub_category   9794 non-null   str
#  15  product_name   9794 non-null   str
#  16  sales          9794 non-null   float64
#  17  quantity       9794 non-null   int64
#  18  discount       9794 non-null   float64
#  19  profit         9794 non-null   float64
#  20  profit_margin  9794 non-null   float64
#  21  order_year     9794 non-null   int32
#  22  order_month    9794 non-null   int32
#  23  delivery_time  9794 non-null   int64
# dtypes: datetime64[us](2), float64(4), int32(2), int64(2), str(14)
# memory usage: 1.8 MB

# %%
df.sample(2)
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 5400  CA-2017-132262 2017-09-21 2017-09-23     First Class    ML-18265
# 8313  CA-2014-161508 2014-07-12 2014-07-16  Standard Class    PV-18985
#
#       customer_name      segment        country         city       state  ...  \
# 5400   Muhammed Lee     Consumer  United States      Seattle  Washington  ...
# 8313  Paul Van Hugh  Home Office  United States  League City       Texas  ...
#
#      sub_category                                   product_name    sales  \
# 5400  Accessories  Sony 64GB Class 10 Micro SDHC R40 Memory Card   71.980
# 8313       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs  512.358
#
#      quantity discount   profit  profit_margin  order_year  order_month  \
# 5400        2      0.0  15.1158       0.210000        2017            9
# 8313        3      0.3 -14.6388      -0.028571        2014            7
#
#       delivery_time
# 5400              2
# 8313              4
#
# [2 rows x 24 columns]

# %%
df.to_csv(r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\final_sales_data.csv", index=False)

# %%
import csv
df.to_csv("C:\\Users\\aadis\\Desktop\\Sales_Data_Analysis\\DATA\\final_sales_data.csv", index=False, quoting=csv.QUOTE_ALL)

# %%
import pandas as pd
import csv

df = pd.read_csv(r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\cleaned_sales_data.csv")

# 🔥 Remove problematic quotes from all string columns
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.replace('"', '', regex=False)

# Save clean file
df.to_csv(
    r"C:\Users\aadis\Desktop\Sales_Data_Analysis\DATA\final_clean_safe.csv",
    index=False,
    quoting=csv.QUOTE_ALL,
    escapechar='\\'
)

print("✅ Fully cleaned CSV ready")
# Out:
# ✅ Fully cleaned CSV ready
# C:\Users\aadis\AppData\Local\Temp\ipykernel_12492\218604118.py:7: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include=['object']).columns:
